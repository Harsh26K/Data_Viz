# %%
import numpy as np 
import pandas as pd

# %%
dataset1 = pd.read_csv('googleplaystore.csv')
dataset2 = pd.read_csv('googleplaystore_user_reviews.csv')

# %%
dataset1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
AppSet = set(dataset2.App.values)
AppSet
# Out:
# {'ADP Mobile Solutions',
#  'Amtrak',
#  'Family Locator - GPS Tracker',
#  'Angry Birds Classic',
#  'GPS Status & Toolbox',
#  'Gay Sugar Daddy Dating & Hookup – Sudy Gay',
#  'Diary with lock password',
#  'Dr. Panda Restaurant 3',
#  'GMX Mail',
#  'Final Fantasy XV: A New Empire',
#  'File Explorer',
#  'BeyondPod Podcast Manager',
#  'HESI A2 Pocket Prep',
#  'Aviary Stickers: Free Pack',
#  'GO SMS Pro - Messenger, Free Themes, Emoji',
#  'Houzz Interior Design Ideas',
#  'Beauty Camera - Selfie Camera',
#  'Buscapé - Ofertas e descontos',
#  'Galactic Core Free Wallpaper',
#  'EatStreet Food Delivery App',
#  'Homework Planner',
#  'BET NOW - Watch Shows',
#  'Bloomberg Professional',
#  'High-Speed Camera (GIF,Burst)',
#  'Chime - Mobile Banking',
#  'Haystack TV: Local & World News - Free',
#  'A+ Mobile',
#  'Classic Calculator',
#  'Google Play Games',
#  'Hinge: Dating & Relationships',
#  'Garden Photo Frames - Garden Photo Editor',
#  '2GIS: directory & navigator',
# ...

# %%
Applist = list(AppSet)
len(AppSet)
# Out:
# 1074

# %%
dataset1.shape[1]
# Out:
# 13

# %%
Category = []
App=[]
i=0
for i in range(0,dataset1.shape[0]):
    value = dataset1['App'][i]
    if value in Applist and ( value not in App):
        App.append(dataset1['App'][i])
        Category.append(dataset1['Category'][i])

# %%
App
# Out:
# ['Coloring book moana',
#  'Garden Coloring Book',
#  '3D Color Pixel by Number - Sandbox Art Coloring',
#  'FlipaClip - Cartoon animation',
#  "Boys Photo Editor - Six Pack & Men's Suit",
#  'Colorfit - Drawing & Coloring',
#  'Animated Photo Editor',
#  'Anime Manga Coloring Book',
#  'Easy Origami Ideas',
#  'Floor Plan Creator',
#  'Drawing Clothes Fashion Ideas',
#  'Canva: Poster, banner, card maker & graphic design',
#  'CDL Practice Test 2018 Edition',
#  'Free VIN Report for Used Cars',
#  'DMV Permit Practice Test 2018 Edition',
#  'Android Auto - Maps, Media, Messaging & Voice',
#  'Best Car Wallpapers',
#  'CarMax – Cars for Sale: Search Used Car Inventory',
#  'BEST CAR SOUNDS',
#  'AutoScout24 Switzerland – Find your new car',
#  'Fuelio: Gas log & costs',
#  'BestCam Selfie-selfie, beauty camera, photo editor',
#  'Beauty Selfie Camera',
#  'Hairstyles step by step',
#  'Filters for Selfie',
#  'Beauty Camera - Selfie Camera',
#  'Girls Hairstyles',
# ...

# %%
Category
# Out:
# ['ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'ART_AND_DESIGN',
#  'AUTO_AND_VEHICLES',
#  'AUTO_AND_VEHICLES',
#  'AUTO_AND_VEHICLES',
#  'AUTO_AND_VEHICLES',
#  'AUTO_AND_VEHICLES',
#  'AUTO_AND_VEHICLES',
#  'AUTO_AND_VEHICLES',
#  'AUTO_AND_VEHICLES',
#  'AUTO_AND_VEHICLES',
#  'BEAUTY',
#  'BEAUTY',
#  'BEAUTY',
#  'BEAUTY',
#  'BEAUTY',
#  'BEAUTY',
#  'BEAUTY',
#  'BEAUTY',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
#  'BOOKS_AND_REFERENCE',
# ...

# %%
d={'App':App,'Category':Category}
new_data = pd.DataFrame(data=d)

# %%
new_data.to_csv('new_data.csv')
